# %% [markdown]
# **Exploration**

# %%
import pandas as pd

# %%
tour_data = pd.read_csv('tour_player_data.csv')

# %%
full_data = pd.read_csv('full_df.csv')

# %%
tour_data
# Out:
#              Player Name  Rounds  Fairway Percentage  Year  Avg Distance  \
# 0         Henrik Stenson    60.0               75.19  2018         291.5
# 1            Ryan Armour   109.0               73.58  2018         283.5
# 2            Chez Reavie    93.0               72.24  2018         286.5
# 3             Ryan Moore    78.0               71.94  2018         289.2
# 4           Brian Stuard   103.0               71.44  2018         278.9
# ...                  ...     ...                 ...   ...           ...
# 2307        Carl Paulson     NaN                 NaN  2012           NaN
# 2308      Peter Tomasulo     NaN                 NaN  2012           NaN
# 2309        Marc Turnesa     NaN                 NaN  2010           NaN
# 2310     Jesper Parnevik     NaN                 NaN  2010           NaN
# 2311  Jim Gallagher, Jr.     NaN                 NaN  2010           NaN
#
#         gir  Average Putts  Average Scrambling  Average Score Points  Wins  \
# ...

# %%
full_data
# Out:
#                player  year  par_4_avg  par_5_avg  drive_avg  weight  \
# 0       Payne Stewart  1987       3.98       4.65      269.9     NaN
# 1            Dan Pohl  1987       3.98       4.63      273.0     NaN
# 2       Lanny Wadkins  1987       3.97       4.74      253.3     NaN
# 3        Paul Azinger  1987       3.98       4.63      269.5     NaN
# 4         David Frost  1987       3.98       4.64      259.2     NaN
# ...               ...   ...        ...        ...        ...     ...
# 7043  Dylan Frittelli  2023       4.11       4.66      303.1   179.0
# 7044     Webb Simpson  2023       4.15       4.56      298.8   185.0
# 7045     Kevin Kisner  2023       4.19       4.85      284.1   165.0
# 7046       Ryan Brehm  2023       4.12       4.71      306.6   220.0
# 7047     Max McGreevy  2023       4.15       4.73      286.4   155.0
#
#              DOB  height_inches   age
# 0            NaN              0   NaN
# 1            NaN              0   NaN
# ...

# %% [markdown]
# **MVP - Target Variable**

# %% [markdown]
# When the average tour player distance is expected to exceed the current usda regulation?
#
# - We have driving distance average by player
# - We have average tour driving distance by year
# - We have expected date of proposed rollback implementation

# %% [markdown]
# **Is driving distance a significant factor for scoring on a Par 4?**

# %% [markdown]
# **Is driving distance a significant factor for scoring on a Par 5?**

# %% [markdown]
# **On average, do taller players on average drive the ball further than shorter players?**

# %% [markdown]
# **Has the overall height of PGA Tour Players increased significantly over time?**

# %% [markdown]
# **Has the overall age of PGA Tour Players increased significantly over time?**

# %% [markdown]
# **What other pivotal technological moments in time impacted the average tour player distance?**
#
# - Titanium -> Graphite
# - Golf Ball Size Reduction

# %% [markdown]
# **Is driving distance the most significant factor for scoring?**

# %% [markdown]
# **How well do the Top drivers of the ball do compared to the average tour player?**
#
# - Top 5 Finishes
# - Top 10 Finishes
# - In The Money

# %% [markdown]
# **How accurate are the top drivers of the ball compared to the average tour player?**
